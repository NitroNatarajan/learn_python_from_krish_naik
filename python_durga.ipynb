# %% [markdown]
# ## Python Programming
#   - Easier Syntax, the syntax seems like communicating using the natural language
#   - It is general purpose, high level programming lang. It can be used to AI, desktop software, Mobile app, data science project, web-dev, game dev.
#   - Python developed by Guido Van Rossam in 1989 at NRI, Netherland
#   - Python made available to the public 1991. Feb 20th 1991..
#   - It is preferred programming lang if we start to learn the programming newly.

# %% [markdown]
# ### Pseudocode
#   - It is a simple way of describing an algorithm in plain english lang or a mix of code like and natural language instruction.
#   - It doesn't follow any specific programming language syntax, making it easier to understand, even for these without programming knowledge.
#   - Pseudocode is a actual step before we write the actual code.

# %%
# Actual pseudocode to find the sum of 2 numbers. 
# Step 1 : Define the function which accept the two number 
# Step 2 : Find the sum and store it in a variable.
# step 3 : Return the sum 

'''
input first number 
input second number 

sum = first_num + second_num
print(sum)
'''
